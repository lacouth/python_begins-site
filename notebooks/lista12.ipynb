# %% [markdown]
# # Lista 12 · Funções
#
# Esta é a primeira lista em que você escreve **funções**, no formato de
# *Python para Telecomunicações*: cada exercício abaixo é uma função, com um
# bloco de testes que já vem pronto no fim do arquivo. Se aparecer a mensagem
# de sucesso, está certo; se aparecer `AssertionError`, a linha apontada é o
# caso que a sua função ainda não atende.
#
# O assunto é o do [Capítulo 12](https://lacouth.github.io/python_begins-site/unidade6-funcoes/12-funcoes/): `def`,
# parâmetro, argumento e `return`. Antes de entregar qualquer exercício,
# pergunte-se: **minha função devolve o valor, ou só mostra na tela?** É o
# defeito mais comum desta lista — a função que imprime o número certo e
# esquece o `return`.
#
# ---
#
# **Antes de tudo: faça a sua cópia.** *Arquivo → Salvar uma cópia no Drive*.
# O caderno aberto direto do repositório é só leitura, e você perde o que
# escrever nele.
#
# **Como usar este caderno:** cada exercício tem duas células. Na primeira,
# escreva a sua solução no lugar do `# TODO`. A segunda tem os testes —
# rode-a e ela diz se a sua função está correta. Não altere a célula de teste.
#
# Se um teste falhar, o Python mostra um `AssertionError` apontando a linha:
# é aquele caso específico que a sua função ainda não atende.
#
# **Se algo ficar inexplicável**, use *Ambiente de execução → Reiniciar e
# executar tudo*. O caderno guarda o que foi executado na ordem em que você
# executou, e não na ordem em que as células aparecem.

# %% [markdown]
# ### Exercício 01
#
# Escreva a função `media`, que recebe três notas e devolve a média
# aritmética delas.
#
# ```python
# media(7.0, 8.0, 9.0)    # -> 8.0
# media(10.0, 10.0, 10.0) # -> 10.0
# ```
#
# Dica: é a mesma conta da Unidade 1 — some as três notas e divida por 3.

# %%
def media(nota1, nota2, nota3):
    """Devolve a média aritmética das três notas."""
    # TODO: some as três notas e divida o resultado por 3
    pass

# %%
# Célula de teste — Exercício 01
assert media(7.0, 8.0, 9.0) == 8.0
assert media(10.0, 10.0, 10.0) == 10.0
assert media(0.0, 0.0, 0.0) == 0.0
assert media(4, 5, 6) == 5.0
print("Exercício 01: todos os testes passaram!")

# %% [markdown]
# ### Exercício 02
#
# Um plano de telefonia inclui uma franquia de minutos por mês; usar além dela
# gera cobrança extra.
#
# Escreva a função `minutos_excedentes`, que recebe os minutos usados no mês e
# a franquia do plano e devolve quantos minutos passaram da franquia — ou `0`,
# se o cliente não passou.
#
# ```python
# minutos_excedentes(220, 200)  # -> 20
# minutos_excedentes(150, 200)  # -> 0
# ```

# %%
def minutos_excedentes(minutos_usados, minutos_franquia):
    """Devolve quantos minutos passaram da franquia, ou 0 se não passou."""
    # TODO: se minutos_usados for maior que minutos_franquia, devolva a
    # diferença; senão, devolva 0
    pass

# %%
# Célula de teste — Exercício 02
assert minutos_excedentes(220, 200) == 20
assert minutos_excedentes(200, 200) == 0
assert minutos_excedentes(0, 200) == 0
assert minutos_excedentes(150, 200) == 0
print("Exercício 02: todos os testes passaram!")

# %% [markdown]
# ### Exercício 03
#
# Escreva a função `troco`, que recebe o valor pago e o valor da compra e
# devolve o troco, arredondado para duas casas decimais.
#
# ```python
# troco(50, 37.50)  # -> 12.5
# troco(20, 20)      # -> 0
# ```
#
# Dica: `round(valor, 2)` arredonda para duas casas — útil porque contas com
# números decimais às vezes sobram casas demais.

# %%
def troco(valor_pago, valor_compra):
    """Devolve o troco (valor_pago - valor_compra), com duas casas."""
    # TODO: calcule a diferença e devolva com round(..., 2)
    pass

# %%
# Célula de teste — Exercício 03
assert troco(50, 37.50) == 12.5
assert troco(20, 20) == 0
assert troco(15, 0) == 15
assert troco(100, 33.33) == 66.67
print("Exercício 03: todos os testes passaram!")

# %% [markdown]
# ### Exercício 04
#
# Escreva a função `preco_com_desconto`, que recebe um preço e um percentual
# de desconto e devolve o preço já com o desconto aplicado, arredondado para
# duas casas decimais.
#
# ```python
# preco_com_desconto(200, 10)   # -> 180.0
# preco_com_desconto(200, 100)  # -> 0.0
# ```

# %%
def preco_com_desconto(preco, percentual_desconto):
    """Devolve o preço após aplicar o percentual de desconto."""
    # TODO: calcule o valor do desconto, subtraia do preço e devolva
    # com round(..., 2)
    pass

# %%
# Célula de teste — Exercício 04
assert preco_com_desconto(200, 10) == 180.0
assert preco_com_desconto(200, 0) == 200.0
assert preco_com_desconto(200, 100) == 0.0
assert preco_com_desconto(50, 50) == 25.0
print("Exercício 04: todos os testes passaram!")

# %% [markdown]
# ### Exercício 05
#
# A conta do mês tem duas partes: a **mensalidade**, que todo mundo paga, e a
# cobrança dos minutos que passaram da franquia. Quem não passou paga só a
# mensalidade.
#
# Escreva a função `conta_do_mes`, que recebe os minutos usados, a franquia do
# plano, o preço do minuto excedente e a mensalidade, e devolve o valor total da
# conta, arredondado para duas casas decimais.
#
# ```python
# conta_do_mes(220, 200, 0.25, 49.90)  # -> 54.9
# conta_do_mes(150, 200, 0.25, 49.90)  # -> 49.9
# ```
#
# Esta é a primeira função da lista que faz **duas coisas em sequência**: decidir
# quanto foi o excedente e só então calcular o total. Escreva o `if` primeiro,
# guarde o excedente numa variável, e faça a conta depois — é mais fácil de ler e
# muito mais fácil de consertar do que tudo numa expressão só.
#
# > Repare que o segundo exemplo devolve `49.9`, e não `49.90`. O Python não
# > guarda o zero do fim: `49.90` e `49.9` são o mesmo número. Quem quer as duas
# > casas na tela usa f-string — mas o que a função **devolve** é o número.

# %%
def conta_do_mes(minutos_usados, minutos_franquia, preco_excedente, mensalidade):
    """Devolve o total da conta: mensalidade mais os minutos que passaram."""
    # TODO: com um if, descubra quantos minutos passaram da franquia
    #       (zero, se o cliente não passou) e guarde numa variável
    # TODO: devolva a mensalidade mais o excedente vezes o preço,
    #       arredondado para duas casas com round(..., 2)
    pass

# %%
# Célula de teste — Exercício 05
assert conta_do_mes(220, 200, 0.25, 49.90) == 54.9
assert conta_do_mes(150, 200, 0.25, 49.90) == 49.9
assert conta_do_mes(200, 200, 0.25, 49.90) == 49.9
assert conta_do_mes(0, 200, 0.25, 49.90) == 49.9
assert conta_do_mes(400, 200, 0.10, 0.0) == 20.0
print("Exercício 05: todos os testes passaram!")

# %% [markdown]
# ### Exercício 06
#
# Escreva a função `classifica_nota`, que recebe uma nota (de 0 a 10) e
# devolve uma classificação:
#
# | Nota | Devolve |
# |---|---|
# | 7 ou mais | `"aprovado"` |
# | de 5 (inclusive) até 7 (exclusive) | `"recuperacao"` |
# | abaixo de 5 | `"reprovado"` |
#
# ```python
# classifica_nota(8.5)  # -> "aprovado"
# classifica_nota(6.0)  # -> "recuperacao"
# classifica_nota(3.0)  # -> "reprovado"
# ```
#
# Dica: é o mesmo formato de `if`/`elif`/`else` da Unidade 2, agora com
# `return` no lugar de `print`.

# %%
def classifica_nota(nota):
    """Classifica a nota em 'aprovado', 'recuperacao' ou 'reprovado'."""
    # TODO: use if/elif/else, com um return em cada caminho
    pass

# %%
# Célula de teste — Exercício 06
assert classifica_nota(8.5) == "aprovado"
assert classifica_nota(7.0) == "aprovado"
assert classifica_nota(6.9) == "recuperacao"
assert classifica_nota(5.0) == "recuperacao"
assert classifica_nota(4.9) == "reprovado"
assert classifica_nota(0.0) == "reprovado"
print("Exercício 06: todos os testes passaram!")
